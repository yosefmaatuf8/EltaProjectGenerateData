# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())


from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o")

from langchain_core.prompts import ChatPromptTemplate

# %%
rule_instance_description = """
Please create a rule Type "System Failure" , The rule types includes the following parameters: speed, type, weight, fuel, altitute , wheels and engine.
The conditions relate to Airplane message.
The Relations between the conditions are "And".  
- Weight should be greater than weight parameter.
- Speed should be greater than speed parameter.
- Type should be equal to type parameter.
- Fuel should be greater than fuel parameter.
- Altitute should be greater than altitute parameter.
- Engine should be greater than engine parameter.
- Wheels should be greater or equal than wheels parameter.
"""

rule_instance_example = {
    "type": "boeing",
    "weight": 200,
    "fuel": 100,
    "altitute": 400,
    "wheels": 1,
    "engine": 1,
    "speed": 150,
    "ruleInstanceName": "System Failure - Wheels",
    "severity": 1,
    "objectName": "Airplan",
    }

rule_type_example = """
{
    "logicType": "structured",
    "structuredlogic": {
      "id": "root",
      "expressionType": null,
      "freeText": null,
      "expressionGroup": null,
      "expressionOperand": "None",
      "leftStatment": null,
      "rightStatment": null,
      "groupType": "And",
      "expressions": [
        {
          "id": "root.1",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "weight",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "weight",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.2",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "speed",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "speed",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.3",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "equal",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "type",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "string",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "type",
              "valueType": "String",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.4",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "fuel",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "fuel",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.5",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "altitute",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "altitute",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.6",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "engine",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "engine",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.7",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greaterOrEqual",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Airplan",
              "field": "wheels",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "wheels",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        }
      ]
    },
    "textualLogic": null,
    "children": [],
    "additionalInformation": {},
    "alertDistributionType": "regular",
    "_id": "fb8e8ef1-e382-43b5-b896-70d254878751",
    "name": "System Failure",
    "lastUpdateTime": "09/16/2024 12:28:31",
    "description": "",
    "parameters": [
      {
        "name": "speed",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "type",
        "type": "String",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "weight",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "fuel",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "altitute",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "wheels",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "engine",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      }
    ],
    "eventDetails": [
      {
        "objectName": "Airplan",
        "objectDescription": null,
        "timeWindowInMilliseconds": 0,
        "useLatest": false
      }
    ]
  }
"""

# %%
rule_instance_to_predict = """
Please create a rule Type "Suspected Person" , The rule types includes following parameters: age, gender, historyRecord, Organization and address.
The conditions relate to Person message.
The Relations between the conditions are "And".

- Age should be greater than age parameter.
- Gender equal to gender parameter.
- HistoryRecod equal or greater than historyRecord parameters.
- Address equal to address parameter.
- Organization equal to organization parameters.
example values:
{
    "gender": "F",
    "historyRecord": 0,
    "organization": "RedCross",
    "address": "",
    "age": "26",
    "ruleInstanceName": "Suspected Person - other",
    "severity": 3,
    "objectName": "Person"
    }"""

# %%
template = """
here its an example with input, and what should be the output: input: {rule_instance_description}, example values: {rule_instance_example}, output: {rule_type_example}.
create output for this input: {to_predict}
"""

# %%
template_params = {"rule_instance_description": rule_instance_description,
                   "rule_instance_example": rule_instance_example,
                   "rule_type_example": rule_type_example,
                   "to_predict": rule_instance_to_predict}

# %%
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | llm
response = chain.invoke(template_params).content

# %%
print(response)
# Out:
# ```json
# {
#     "logicType": "structured",
#     "structuredlogic": {
#       "id": "root",
#       "expressionType": null,
#       "freeText": null,
#       "expressionGroup": null,
#       "expressionOperand": "None",
#       "leftStatment": null,
#       "rightStatment": null,
#       "groupType": "And",
#       "expressions": [
#         {
#           "id": "root.1",
#           "expressionType": {
#             "leftOption": "basic",
#             "rightOption": "parameterValue"
#           },
#           "freeText": null,
#           "expressionGroup": null,
#           "expressionOperand": "greater",
#           "leftStatment": [
#             {
#               "atomType": "property",
#               "objectName": "Person",
#               "field": "age",
#               "fieldType": null,
#               "isInputObject": true,
#               "value": null,
#               "valueType": "int32",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "rightStatment": [
#             {
#               "atomType": "parameterValue",
#               "objectName": null,
#               "field": null,
#               "fieldType": null,
#               "isInputObject": false,
#               "value": "age",
#               "valueType": "Int",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "groupType": "None",
#           "expressions": null
#         },
#         {
#           "id": "root.2",
#           "expressionType": {
#             "leftOption": "basic",
#             "rightOption": "parameterValue"
#           },
#           "freeText": null,
#           "expressionGroup": null,
#           "expressionOperand": "equal",
#           "leftStatment": [
#             {
#               "atomType": "property",
#               "objectName": "Person",
#               "field": "gender",
#               "fieldType": null,
#               "isInputObject": true,
#               "value": null,
#               "valueType": "string",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "rightStatment": [
#             {
#               "atomType": "parameterValue",
#               "objectName": null,
#               "field": null,
#               "fieldType": null,
#               "isInputObject": false,
#               "value": "gender",
#               "valueType": "String",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "groupType": "None",
#           "expressions": null
#         },
#         {
#           "id": "root.3",
#           "expressionType": {
#             "leftOption": "basic",
#             "rightOption": "parameterValue"
#           },
#           "freeText": null,
#           "expressionGroup": null,
#           "expressionOperand": "greaterOrEqual",
#           "leftStatment": [
#             {
#               "atomType": "property",
#               "objectName": "Person",
#               "field": "historyRecord",
#               "fieldType": null,
#               "isInputObject": true,
#               "value": null,
#               "valueType": "int32",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "rightStatment": [
#             {
#               "atomType": "parameterValue",
#               "objectName": null,
#               "field": null,
#               "fieldType": null,
#               "isInputObject": false,
#               "value": "historyRecord",
#               "valueType": "Int",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "groupType": "None",
#           "expressions": null
#         },
#         {
#           "id": "root.4",
#           "expressionType": {
#             "leftOption": "basic",
#             "rightOption": "parameterValue"
#           },
#           "freeText": null,
#           "expressionGroup": null,
#           "expressionOperand": "equal",
#           "leftStatment": [
#             {
#               "atomType": "property",
#               "objectName": "Person",
#               "field": "address",
#               "fieldType": null,
#               "isInputObject": true,
#               "value": null,
#               "valueType": "string",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "rightStatment": [
#             {
#               "atomType": "parameterValue",
#               "objectName": null,
#               "field": null,
#               "fieldType": null,
#               "isInputObject": false,
#               "value": "address",
#               "valueType": "String",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "groupType": "None",
#           "expressions": null
#         },
#         {
#           "id": "root.5",
#           "expressionType": {
#             "leftOption": "basic",
#             "rightOption": "parameterValue"
#           },
#           "freeText": null,
#           "expressionGroup": null,
#           "expressionOperand": "equal",
#           "leftStatment": [
#             {
#               "atomType": "property",
#               "objectName": "Person",
#               "field": "organization",
#               "fieldType": null,
#               "isInputObject": true,
#               "value": null,
#               "valueType": "string",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "rightStatment": [
#             {
#               "atomType": "parameterValue",
#               "objectName": null,
#               "field": null,
#               "fieldType": null,
#               "isInputObject": false,
#               "value": "organization",
#               "valueType": "String",
#               "operandType": null,
#               "functionType": null
#             }
#           ],
#           "groupType": "None",
#           "expressions": null
#         }
#       ]
#     },
#     "textualLogic": null,
#     "children": [],
#     "additionalInformation": {},
#     "alertDistributionType": "regular",
#     "_id": "a1b2c3d4-e5f6-7890-abcd-ef1234567890",
#     "name": "Suspected Person",
#     "lastUpdateTime": "09/16/2024 12:28:31",
#     "description": "",
#     "parameters": [
#       {
#         "name": "age",
#         "type": "Int",
#         "defaultValue": "",
#         "description": "",
#         "displayName": "",
#         "repositoryName": "",
#         "mandatory": false,
#         "selectableValue": []
#       },
#       {
#         "name": "gender",
#         "type": "String",
#         "defaultValue": "",
#         "description": "",
#         "displayName": "",
#         "repositoryName": "",
#         "mandatory": false,
#         "selectableValue": []
#       },
#       {
#         "name": "historyRecord",
#         "type": "Int",
#         "defaultValue": "",
#         "description": "",
#         "displayName": "",
#         "repositoryName": "",
#         "mandatory": false,
#         "selectableValue": []
#       },
#       {
#         "name": "address",
#         "type": "String",
#         "defaultValue": "",
#         "description": "",
#         "displayName": "",
#         "repositoryName": "",
#         "mandatory": false,
#         "selectableValue": []
#       },
#       {
#         "name": "organization",
#         "type": "String",
#         "defaultValue": "",
#         "description": "",
#         "displayName": "",
#         "repositoryName": "",
#         "mandatory": false,
#         "selectableValue": []
#       }
#     ],
#     "eventDetails": [
#       {
#         "objectName": "Person",
#         "objectDescription": null,
#         "timeWindowInMilliseconds": 0,
#         "useLatest": false
#       }
#     ]
# }
# ```

# %%
target = """
{
  "logicType": "structured",
  "structuredlogic": {
    "id": "root",
    "expressionType": null,
    "freeText": null,
    "expressionGroup": null,
    "expressionOperand": "None",
    "leftStatment": null,
    "rightStatment": null,
    "groupType": "And",
    "expressions": [
      {
        "id": "root.1",
        "expressionType": {
          "leftOption": "basic",
          "rightOption": "parameterValue"
        },
        "freeText": null,
        "expressionGroup": null,
        "expressionOperand": "greater",
        "leftStatment": [
          {
            "atomType": "property",
            "objectName": "Person",
            "field": "age",
            "fieldType": null,
            "isInputObject": true,
            "value": null,
            "valueType": "int32",
            "operandType": null,
            "functionType": null
          }
        ],
        "rightStatment": [
          {
            "atomType": "parameterValue",
            "objectName": null,
            "field": null,
            "fieldType": null,
            "isInputObject": false,
            "value": "age",
            "valueType": "Int",
            "operandType": null,
            "functionType": null
          }
        ],
        "groupType": "None",
        "expressions": null
      },
      {
        "id": "root.2",
        "expressionType": {
          "leftOption": "basic",
          "rightOption": "parameterValue"
        },
        "freeText": null,
        "expressionGroup": null,
        "expressionOperand": "equal",
        "leftStatment": [
          {
            "atomType": "property",
            "objectName": "Person",
            "field": "gender",
            "fieldType": null,
            "isInputObject": true,
            "value": null,
            "valueType": "string",
            "operandType": null,
            "functionType": null
          }
        ],
        "rightStatment": [
          {
            "atomType": "parameterValue",
            "objectName": null,
            "field": null,
            "fieldType": null,
            "isInputObject": false,
            "value": "gender",
            "valueType": "String",
            "operandType": null,
            "functionType": null
          }
        ],
        "groupType": "None",
        "expressions": null
      },
      {
        "id": "root.3",
        "expressionType": {
          "leftOption": "basic",
          "rightOption": "parameterValue"
        },
        "freeText": null,
        "expressionGroup": null,
        "expressionOperand": "greaterOrEqual",
        "leftStatment": [
          {
            "atomType": "property",
            "objectName": "Person",
            "field": "historyRecord",
            "fieldType": null,
            "isInputObject": true,
            "value": null,
            "valueType": "int32",
            "operandType": null,
            "functionType": null
          }
        ],
        "rightStatment": [
          {
            "atomType": "parameterValue",
            "objectName": null,
            "field": null,
            "fieldType": null,
            "isInputObject": false,
            "value": "historyRecord",
            "valueType": "Int",
            "operandType": null,
            "functionType": null
          }
        ],
        "groupType": "None",
        "expressions": null
      },
      {
        "id": "root.4",
        "expressionType": {
          "leftOption": "basic",
          "rightOption": "parameterValue"
        },
        "freeText": null,
        "expressionGroup": null,
        "expressionOperand": "equal",
        "leftStatment": [
          {
            "atomType": "property",
            "objectName": "Person",
            "field": "address",
            "fieldType": null,
            "isInputObject": true,
            "value": null,
            "valueType": "string",
            "operandType": null,
            "functionType": null
          }
        ],
        "rightStatment": [
          {
            "atomType": "parameterValue",
            "objectName": null,
            "field": null,
            "fieldType": null,
            "isInputObject": false,
            "value": "address",
            "valueType": "String",
            "operandType": null,
            "functionType": null
          }
        ],
        "groupType": "None",
        "expressions": null
      },
      {
        "id": "root.5",
        "expressionType": {
          "leftOption": "basic",
          "rightOption": "parameterValue"
        },
        "freeText": null,
        "expressionGroup": null,
        "expressionOperand": "equal",
        "leftStatment": [
          {
            "atomType": "property",
            "objectName": "Person",
            "field": "organization",
            "fieldType": null,
            "isInputObject": true,
            "value": null,
            "valueType": "string",
            "operandType": null,
            "functionType": null
          }
        ],
        "rightStatment": [
          {
            "atomType": "parameterValue",
            "objectName": null,
            "field": null,
            "fieldType": null,
            "isInputObject": false,
            "value": "organization",
            "valueType": "String",
            "operandType": null,
            "functionType": null
          }
        ],
        "groupType": "None",
        "expressions": null
      }
    ]
  },
  "textualLogic": null,
  "children": [],
  "additionalInformation": {},
  "alertDistributionType": "regular",
  "_id": "361c26cb-b6e7-4035-8b48-1edd57c0c3e5",
  "name": "Suspected Person",
  "lastUpdateTime": "09/16/2024 09:57:14",
  "description": "",
  "parameters": [
    {
      "name": "age",
      "type": "Int",
      "defaultValue": "",
      "description": "",
      "displayName": "",
      "repositoryName": "",
      "mandatory": false,
      "selectableValue": []
    },
    {
      "name": "gender",
      "type": "String",
      "defaultValue": "",
      "description": "",
      "displayName": "",
      "repositoryName": "",
      "mandatory": false,
      "selectableValue": []
    },
    {
      "name": "historyRecord",
      "type": "Int",
      "defaultValue": "",
      "description": "",
      "displayName": "",
      "repositoryName": "",
      "mandatory": false,
      "selectableValue": []
    },
    {
      "name": "organization",
      "type": "String",
      "defaultValue": "",
      "description": "",
      "displayName": "",
      "repositoryName": "",
      "mandatory": false,
      "selectableValue": []
    },
    {
      "name": "address",
      "type": "String",
      "defaultValue": "",
      "description": "",
      "displayName": "",
      "repositoryName": "",
      "mandatory": false,
      "selectableValue": []
    }
  ],
  "eventDetails": [
    {
      "objectName": "Person",
      "objectDescription": null,
      "timeWindowInMilliseconds": 0,
      "useLatest": false
    }
  ]
}
"""

# %%
response_str = """
{
    "logicType": "structured",
    "structuredlogic": {
      "id": "root",
      "expressionType": null,
      "freeText": null,
      "expressionGroup": null,
      "expressionOperand": "None",
      "leftStatment": null,
      "rightStatment": null,
      "groupType": "And",
      "expressions": [
        {
          "id": "root.1",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greater",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Person",
              "field": "age",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "age",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.2",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "equal",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Person",
              "field": "gender",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "string",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "gender",
              "valueType": "String",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.3",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "greaterOrEqual",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Person",
              "field": "historyRecord",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "int32",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "historyRecord",
              "valueType": "Int",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.4",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "equal",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Person",
              "field": "address",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "string",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "address",
              "valueType": "String",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        },
        {
          "id": "root.5",
          "expressionType": {
            "leftOption": "basic",
            "rightOption": "parameterValue"
          },
          "freeText": null,
          "expressionGroup": null,
          "expressionOperand": "equal",
          "leftStatment": [
            {
              "atomType": "property",
              "objectName": "Person",
              "field": "organization",
              "fieldType": null,
              "isInputObject": true,
              "value": null,
              "valueType": "string",
              "operandType": null,
              "functionType": null
            }
          ],
          "rightStatment": [
            {
              "atomType": "parameterValue",
              "objectName": null,
              "field": null,
              "fieldType": null,
              "isInputObject": false,
              "value": "organization",
              "valueType": "String",
              "operandType": null,
              "functionType": null
            }
          ],
          "groupType": "None",
          "expressions": null
        }
      ]
    },
    "textualLogic": null,
    "children": [],
    "additionalInformation": {},
    "alertDistributionType": "regular",
    "_id": "a1b2c3d4-e5f6-7890-abcd-ef1234567890",
    "name": "Suspected Person",
    "lastUpdateTime": "09/16/2024 12:28:31",
    "description": "",
    "parameters": [
      {
        "name": "age",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "gender",
        "type": "String",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "historyRecord",
        "type": "Int",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "address",
        "type": "String",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      },
      {
        "name": "organization",
        "type": "String",
        "defaultValue": "",
        "description": "",
        "displayName": "",
        "repositoryName": "",
        "mandatory": false,
        "selectableValue": []
      }
    ],
    "eventDetails": [
      {
        "objectName": "Person",
        "objectDescription": null,
        "timeWindowInMilliseconds": 0,
        "useLatest": false
      }
    ]
}
"""
